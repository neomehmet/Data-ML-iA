# %%
import pandas as pd

# %%
df = pd.DataFrame(  {"groups" : ["A","B","C","A","B","C"],
                     "data": [10,11,41,31,55,30]}, columns=["groups","data"])

# %%
df
# Out:
#   groups  data
# 0      A    10
# 1      B    11
# 2      C    41
# 3      A    31
# 4      B    55
# 5      C    30

# %%
df.groupby("groups").mean()
# Out:
#         data
# groups
# A       20.5
# B       33.0
# C       35.5

# %%
import seaborn as sns

# %%
df1 = sns.load_dataset("planets")

# %%
df1.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df1.groupby("method")["orbital_period"].mean()  #groups depend by groups and calculate mean of orbital period
# Out:
# method
# Astrometry                          631.180000
# Eclipse Timing Variations          4751.644444
# Imaging                          118247.737500
# Microlensing                       3153.571429
# Orbital Brightness Modulation         0.709307
# Pulsar Timing                      7343.021201
# Pulsation Timing Variations        1170.000000
# Radial Velocity                     823.354680
# Transit                              21.102073
# Transit Timing Variations            79.783500
# Name: orbital_period, dtype: float64

# %%
df1.groupby("method").describe()
# Out:
#                               number                                           \
#                                count      mean       std  min  25%  50%   75%
# method
# Astrometry                       2.0  1.000000  0.000000  1.0  1.0  1.0  1.00
# Eclipse Timing Variations        9.0  1.666667  0.500000  1.0  1.0  2.0  2.00
# Imaging                         38.0  1.315789  0.933035  1.0  1.0  1.0  1.00
# Microlensing                    23.0  1.173913  0.387553  1.0  1.0  1.0  1.00
# Orbital Brightness Modulation    3.0  1.666667  0.577350  1.0  1.5  2.0  2.00
# Pulsar Timing                    5.0  2.200000  1.095445  1.0  1.0  3.0  3.00
# Pulsation Timing Variations      1.0  1.000000       NaN  1.0  1.0  1.0  1.00
# Radial Velocity                553.0  1.721519  1.157141  1.0  1.0  1.0  2.00
# Transit                        397.0  1.954660  1.399119  1.0  1.0  1.0  2.00
# Transit Timing Variations        4.0  2.250000  0.500000  2.0  2.0  2.0  2.25
#
# ...

# %%
df1.groupby("method").aggregate({"distance":"min", "mass":"max"} )
# Out:
#                                distance   mass
# method
# Astrometry                        14.98    NaN
# Eclipse Timing Variations        130.72   6.05
# Imaging                            7.69    NaN
# Microlensing                    1760.00    NaN
# Orbital Brightness Modulation   1180.00    NaN
# Pulsar Timing                   1200.00    NaN
# Pulsation Timing Variations         NaN    NaN
# Radial Velocity                    1.35  25.00
# Transit                           38.00   1.47
# Transit Timing Variations        339.00    NaN

# %%
df
# Out:
#   groups  data
# 0      A    10
# 1      B    11
# 2      C    41
# 3      A    31
# 4      B    55
# 5      C    30

# %%
df.groupby("groups").aggregate( {"data":"max", "data":"min", "data":"mean"} )
# Out:
#         data
# groups
# A       20.5
# B       33.0
# C       35.5
