# %%
import numpy as np
import pandas as pd
data = np.random.randint(0,30, (5,3))

# %%
df1 = pd.DataFrame(data, columns=["col1","col2","col3"])

# %%
df2 = df1+1000

# %%
df1
# Out:
#    col1  col2  col3
# 0    12    11     2
# 1    13    16    12
# 2    20    23    17
# 3    26     6    22
# 4    24     9     4

# %%
df2
# Out:
#    col1  col2  col3
# 0  1012  1011  1002
# 1  1013  1016  1012
# 2  1020  1023  1017
# 3  1026  1006  1022
# 4  1024  1009  1004

# %%
df3 = pd.concat([df1,df2])

# %%
df3 ## keeps indexes
# Out:
#    col1  col2  col3
# 0    12    11     2
# 1    13    16    12
# 2    20    23    17
# 3    26     6    22
# 4    24     9     4
# 0  1012  1011  1002
# 1  1013  1016  1012
# 2  1020  1023  1017
# 3  1026  1006  1022
# 4  1024  1009  1004

# %%
# ?pd.concat

# %%
df4 = pd.concat([df1,df2], ignore_index=True)

# %%
df4
# Out:
#    col1  col2  col3
# 0    12    11     2
# 1    13    16    12
# 2    20    23    17
# 3    26     6    22
# 4    24     9     4
# 5  1012  1011  1002
# 6  1013  1016  1012
# 7  1020  1023  1017
# 8  1026  1006  1022
# 9  1024  1009  1004

# %%
df1.columns = ["col2","col3","var3"] #

# %%
pd.concat([df1,df2], ignore_index=True)   #different columns names
# Out:
#    col2  col3  var3    col1
# 0    12    11   2.0     NaN
# 1    13    16  12.0     NaN
# 2    20    23  17.0     NaN
# 3    26     6  22.0     NaN
# 4    24     9   4.0     NaN
# 5  1011  1002   NaN  1012.0
# 6  1016  1012   NaN  1013.0
# 7  1023  1017   NaN  1020.0
# 8  1006  1022   NaN  1026.0
# 9  1009  1004   NaN  1024.0

# %%
pd.concat([df1,df2],join="inner")
# Out:
#    col2  col3
# 0    12    11
# 1    13    16
# 2    20    23
# 3    26     6
# 4    24     9
# 0  1011  1002
# 1  1016  1012
# 2  1023  1017
# 3  1006  1022
# 4  1009  1004

# %%
pd.concat([df1,df2], join_axes =[df1.columns])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32384\2887273201.py in <module>
# ----> 1 pd.concat([df1,df2], join_axes =[df1.columns])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: concat() got an unexpected keyword argument 'join_axes'
